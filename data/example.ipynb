# %%
import pandas as pd

df = pd.read_csv('TaiwanSpecies20200427_UTF8.csv',  escapechar='\\', encoding='utf-8')

# print basic csv info
print (df.info())

# display first 5 rows
display(df.head())

# only get 2 columns
df2 = df[['name', 'family_c']]
display(df2)

df2.to_csv('output.csv')
# Out:
# /usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (17,18,20,21,29,30,31,36,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154798 entries, 0 to 154797
# Data columns (total 38 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   kingdom               154798 non-null  object
#  1   kingdom_c             154798 non-null  object
#  2   phylum                154306 non-null  object
#  3   phylum_c              154305 non-null  object
#  4   class                 154201 non-null  object
#  5   class_c               154198 non-null  object
#  6   order                 154236 non-null  object
#  7   order_c               154162 non-null  object
#  8   family                152472 non-null  object
# ...
